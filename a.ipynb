# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 2.
# Suppose a coin has probability p of falling heads up. If we flip the coin many times, we would expect
# the proportion of heads to be near p. Take p = 0.3 and n = 1000 and simulate n coin flips. Plot the
# proportion of heads as a function of n. Repeat for p = 0.03.
n = 1000
p = 0.3
x = np.arange(1, n + 1)
y = np.zeros(n)
heads_so_far = 0
for i in range(n):
    # flip a coin
    if np.random.random() < p:
        heads_so_far += 1
    # record the proportion of heads
    y[i] = heads_so_far / (i + 1)

# plot the proportion of heads as a function of n
plt.plot(x, y, 'r-', label='simulated')
# plot the expected proportion of heads
plt.plot(x, p * x / n, 'b-', label='expected')
plt.xlabel('n', color='white')
plt.ylabel('proportion of heads', color='white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.grid(True)
plt.legend()
plt.show()

# %%
n = 1000
p = 0.03
x = np.arange(1, n + 1)
y = np.zeros(n)
heads_so_far = 0
for i in range(n):
    # flip a coin
    if np.random.random() < p:
        heads_so_far += 1
    # record the proportion of heads
    y[i] = heads_so_far / (i + 1)

# plot the proportion of heads as a function of n
plt.plot(x, y, 'r-', label='simulated')
# plot the expected proportion of heads
plt.plot(x, p * x / n, 'b-', label='expected')
plt.xlabel('n', color='white')
plt.ylabel('proportion of heads', color='white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.grid(True)
plt.legend()
plt.show()

# %%
# 5.
# Let X be N(0, 1) and let Y = e^X.
# 1. Find the PDF for Y. Plot it.
# 2. Generate a vector x = (x1, ..., x10000) consisting of 10,000 random standard Normals. Let y = (y1, ....., y10000) where yi = e^xi.
# Draw a histogram of y and compare it to the pdf you found in part # 1.
X = np.random.normal(0, 1, 10000)
# plot the PDF
plt.hist(X, bins=100, label='PDF of X')
plt.show()

# %%
# 5.1
# PDF of Y
# PDF of Y = e^X is the same as the PDF of X

# %%
# 5.2
# 2. Generate a vector x = (x1, ..., x10000) consisting of 10,000 random standard Normals. Let y = (y1, ....., y10000) where yi = e^xi. Draw a histogram of y and compare it to the pdf you found in part # 1.
plt.hist(np.exp(X), bins=100, label='PDF of Y')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %%
# 12. For the airline-passenger-satisfaction data set
# 1. Visualise the number of male to female passengers using a histogram.
# 2. Visualise the number of loyal customers to disloyal customer using a pie chart.
# 3. What is the average delay in departure experienced by male passengers?
# 4. What percentage of total passengers are below the age of 40?
# 5. What is the shortest and longest distance a flight travels?
# 6. Visualise the age of passengers using a box plot and explain your findings.
import pandas as pd
df = pd.read_csv('./airline_passenger_satisfaction_dataset.csv')
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
# DO BETTER CODE
# 1. 
genders = []
for i in range(len(df)):
    if df['Gender'][i] == 'Male':
        genders.append(1)
    else:
        genders.append(2)
plt.hist(genders, zorder=3)
plt.grid(True, zorder=0)
plt.xticks(np.arange(1, 3), ["Male", "Female"], color='white')
plt.yticks(color='white')
plt.show()

# %%
# 2.
loyal = [0, 0]
for i in range(len(df)):
    if df['Customer Type'][i][0] == 'L':
        loyal[0] += 1
    else:
        loyal[1] += 1
plt.pie(loyal, labels=["Loyal", "Disloyal"], autopct='%1.1f%%', shadow=True, startangle=90)
# Set label color to white
plt.legend()
plt.show()

# %%
# 3.
total_delay = 0
for i in range(len(df)):
    if df['Gender'][i] == 'Male':
        total_delay += df['Departure Delay in Minutes'][i]
print(f"Average Departure Delay Faced by Males: {total_delay/len(df[df['Gender'] == 'Male'].index)}")
# Out:
# Average Departure Delay Faced by Males: 14.929499579889404

# %%
# 4.
percent = len(df[df['Age'] < 40].index)/len(df.index)
print(f"{percent*100}% Passengers are below 40")
# Out:
# 49.45526639975362% Passengers are below 40

# %%
# 5.
print(f"Minimum Flight Distance: {min(df['Flight Distance'])}")
print(f"Maximum Flight Distance: {max(df['Flight Distance'])}")
# Out:
# Minimum Flight Distance: 31
# Maximum Flight Distance: 4983

# %%
# 6.
B = plt.boxplot(df['Age'])
print([item.get_ydata() for item in B['whiskers']])
plt.yticks(color='white')
plt.grid(True)
plt.show()
# FINDINGS :
# The age distribution is skewed right.
# Median is 40
# Maximum age is 85
# Minimum age is 7
# 25% of the passengers are below 27
# 75% of the passengers are below 51
# Out:
# [array([27.,  7.]), array([51., 85.])]

# %%
# 10. For the Rdatasets data set
# 1. Visualise the gender distribution using a pie chart and calculate what percentage of teachers are male.
# 2. If one teacher is selected at random, what is the probability that the selected teacher is a professor?
# 3. What are the top 5 highest and lowest salaries?
# 4. Visualise the salaries of professors using a box plot and explain your findings.
# 5. What is the average of years spent during service of a professor and associate professor?
# 6. What is probability that a professor is female and belongs to discipline B?

df = pd.read_csv('./Salaries.csv')
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
# 1. Visualise the gender distribution using a pie chart and calculate what percentage of teachers are male.
males = 0
females = 0
for i in range(len(df)):
    if df['sex'][i] == 'Male':
        males += 1
    else:
        females += 1

plt.pie([males, females], labels=["Males", "Females"], autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend()
plt.show()

# %%
# df['rank'].value_counts().plot(kind='pie', legend=True, autopct='%1.3f%%', shadow=True, startangle=90)
# print("As we can see from the chart, the probability of a teacher being a professor is 67.003%")
# 2.
print(f"Probability of a randomly selected teacher being a professor is: {len(df[df['rank'] == 'Prof'].index)/len(df.index)*100:.3f}%")
# Out:
# Probability of a randomly selected teacher being a professor is: 67.003%

# %%
# 3.
salaries = df['salary'].tolist()
salaries.sort()
print(f"Top 5 salaries: {salaries[-5:]}")
print(f"Bottom 5 salaries: {salaries[:5]}")
# Out:
# Top 5 salaries: [193000, 194800, 204000, 205500, 231545]
# Bottom 5 salaries: [57800, 62884, 63100, 63900, 67559]

# %%
# 4.
B = plt.boxplot(df['salary'])
# Find mean and median of salaries
print([item.get_ydata() for item in B['whiskers']])
# Find median of salaries from the box plot
plt.yticks(color='white')
plt.grid(True)
plt.show()
# FINDINGS :
# The salaries are skewed right.
# The top 4 salaries are actually outliers
# Out:
# [array([91000., 57800.]), array([134185., 194800.])]

# %%
# 5.
print(f"Average years of service of a Professor: {df[df['rank'] == 'Prof']['yrs.service'].mean()}")
print(f"Average years of service of an Assosiate Professor: {df[df['rank'] == 'AsstProf']['yrs.service'].mean()}")
# Out:
# Average years of service of a Professor: 22.81578947368421
# Average years of service of an Assosiate Professor: 2.373134328358209

# %%
# 6.
cnt = 0
df1 = df[df['rank'] == 'Prof']
for i in range(len(df1)):
    if df1.iloc[i]['sex'] == 'Female' and df1.iloc[i]['discipline'] == 'B':
        cnt += 1
print(f"Probability that the Professor is female and belongs to discipline B is {cnt/len(df1.index)*100:.3f}%")
# Out:
# Probability that the Professor is female and belongs to discipline B is 3.759%

# %%
# 13. For the diabetes data set
# 1. Visualise the age of patients using a histogram and tell how many patients are of the age 40?
# 2. What percentage of male patients are above 50 years old?
# 3. Visualise the number of patient experiencing muscle stiffness based on gender with help of Count-plot.
# 4. What percentage of people experienced sudden weight loss and were tested positive for diabetes?
# 5. Who is having greater probability of testing positive, a male with visual blurring or a female with delay healing? Visualise the probability of both cases using a bar chart.
# 6. Based on the data, which gender has greater probability of testing positive for diabetes?

df = pd.read_csv('./diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 1. 
ages = df['Age']
p, bins, rects = plt.hist(ages, bins=np.arange(ages.min(), ages.max()+1))
plt.xticks(color='white')
plt.yticks(color='white')
plt.xlabel("Age", color='white')
plt.ylabel("Frequency", color='white')

# Find the number of patients of age 40
for rect in rects:
    x = rect.get_x()
    # print(x)
    if x == 40:
        print("The number of patients with age 40 are",int(rect.get_height()))

plt.show()
# Out:
# The number of patients with age 40 are 13

# %%
# 2.  DOUBT: NO GENDER COLUMN IN DATASET
try:
    males = 0
    males_above_50 = 0
    for i in range(len(df)):
        age = df['Age'][i]
        gender = df['sex'][i]
        if gender == 'Male':
            males += 1
            if age > 50:
                males_above_50 += 1
    print(f"The Percentage of Male Patients above 50 is: {(males*100)/males_above_50}")
except Exception as e:
    print("ERROR RELATED TO: ", end='')
    print(e)
# Out:
# ERROR RELATED TO: 'Age'

# %%
# 14. For the customer-churn-prediction-2020 data set
# 1. Visualise how many people have international plan on there mobile from each of the state using a
# histogram.
# 2. What is the probability that a customer has both, a voice mail plan and an international plan?
# 3. Visualise the number of month a customer has been with the current telecom provider using a box
# plot and explain your findings.
# 4. Visualise the number of day calls versus the number of night calls for state of New York(NY) using
# pie chart.
# 5. Which state has the highest number of calls to customer service?
# 6. If a customer is churned then what is the probability that the customer has been with the current
# telecom provider for more than 75 months?

df = pd.read_csv('./customer-churn-prediction-2020.csv')
df.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# ...

# %%
# 1. 
states_international_plan = df[['state','international_plan']]

states = []
for i in range(len(states_international_plan)):
    if states_international_plan.iloc[i]['international_plan'] == 'yes':
        states.append(states_international_plan.iloc[i]['state'])

f = plt.figure()

# set width of plot
f.set_figwidth(15)
f.set_figheight(5)

# To plot histogram of an array of lists
p = pd.Series(states).value_counts().plot(kind='bar')

# Write height of bar on top of bars
rects = p.patches
  
for rect in rects:
    height = rect.get_height()
    if(height > 0):
        p.text(rect.get_x() + rect.get_width() / 2, height+0.01, str(height), ha='center', va='bottom')

plt.xticks(color='white', rotation=90)
plt.yticks(color='white')
plt.xlabel("State", color='white')
plt.ylabel("# of people with International Plan", color='white')
plt.show()

# %%
# 2.
number = 0
for i in range(len(df)):
    if df['international_plan'][i] == 'yes' and df['voice_mail_plan'][i] == 'yes':
        number += 1

print(f"Probability that a customer has both, a voice mail plan and an international plan is {number/len(df.index)*100:.3f}%")
# Out:
# Probability that a customer has both, a voice mail plan and an international plan is 2.447%

# %%
# 3.
s = df['account_length']
s.plot(kind='box')
plt.grid(True)
print([item.get_ydata() for item in B['whiskers']])

# FINDINGS :
# The number of months a customer has been with the current telecom provider is skewed right.
# TODO. COMPLETE FINDINGS FROM BOX PLOT
# Out:
# [array([91000., 57800.]), array([134185., 194800.])]

# %%
# 4. 
df1 = df[df['state'] == 'NY']
number_of_day_calls = 0
number_of_night_calls = 0
for i in range(len(df1)):
    if df1.iloc[i]['total_day_calls'] > 0:
        number_of_day_calls += df1.iloc[i]['total_day_calls']
    if df1.iloc[i]['total_night_calls'] > 0:
        number_of_night_calls += df1.iloc[i]['total_night_calls']

# To plot pie chart
labels = ['Day Calls', 'Night Calls']
sizes = [number_of_day_calls, number_of_night_calls]
colors = ['gold', 'yellowgreen']
explode = (0.1, 0.1)

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.show()

# %%
# 5. 
state_call_frequency = df[['state','number_customer_service_calls']]

# Aggregate the number of calls to customer service by state
state_call_frequency = state_call_frequency.groupby('state').sum()

# Find the state with the highest number of calls to customer service
state_call_frequency.sort_values(by='number_customer_service_calls', ascending=False, inplace=True)

# Print the state with the highest number of calls to customer service
print(state_call_frequency.head(1))
# Out:
#        number_customer_service_calls
# state
# WV                               235

# %%
# 6.
df1 = df[df['churn'] == 'yes']

customers_with_more_than_75_months = 0
for i in range(len(df1)):
    if df1.iloc[i]['account_length'] > 75:
        customers_with_more_than_75_months += 1

print(f"Probability that a customer has been with the current telecom provider for more than 75 months is {(customers_with_more_than_75_months*100)/len(df1.index):.3f}%")
# Out:
# Probability that a customer has been with the current telecom provider for more than 75 months is 75.084%
